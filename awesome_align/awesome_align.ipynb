# %%
# !git clone https://github.com/neulab/awesome-align.git
# %cd awesome-align
# Out:
# Cloning into 'awesome-align'...
# remote: Enumerating objects: 343, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 343 (delta 100), reused 86 (delta 86), pack-reused 228 (from 1)
# Receiving objects: 100% (343/343), 596.38 KiB | 1.94 MiB/s, done.
# Resolving deltas: 100% (207/207), done.
# /content/awesome-align

# %%
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 106.5 MB/s eta 0:00:00
# ...

# %%
# !pip install awesome-align
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/awesome_align-0.1.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
# !bash train_alignments.sh
# Out:
# Starting basic training...
# 2025-06-02 10:29:39.589622: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748860179.829545     961 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748860179.890869     961 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-02 10:29:40.403046: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !bash extract_alignments.sh
# Out:
# 2025-06-02 10:34:56.994629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748860497.014677    2332 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748860497.021194    2332 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-02 10:34:57.041571: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import shutil

folder_path = "/content/awesome-align/awesome_align_model/checkpoint-4000"  
shutil.rmtree(folder_path)

# %%
# !zip -r awesome_align_model_llm_dict_2k.zip /content/awesome-align/awesome_align_model_llm_dict_2k_lemma/
# Out:
#   adding: content/awesome-align/awesome_align_model_llm_dict_2k_lemma/ (stored 0%)
#   adding: content/awesome-align/awesome_align_model_llm_dict_2k_lemma/special_tokens_map.json (deflated 40%)
#   adding: content/awesome-align/awesome_align_model_llm_dict_2k_lemma/tokenizer_config.json (stored 0%)
#   adding: content/awesome-align/awesome_align_model_llm_dict_2k_lemma/training_args.bin (deflated 50%)
#   adding: content/awesome-align/awesome_align_model_llm_dict_2k_lemma/pytorch_model.bin (deflated 7%)
#   adding: content/awesome-align/awesome_align_model_llm_dict_2k_lemma/config.json (deflated 57%)
#   adding: content/awesome-align/awesome_align_model_llm_dict_2k_lemma/vocab.txt (deflated 45%)

# %%
from google.colab import files
files.download("awesome_align_model_llm_dict_2k.zip")
